# %% [raw]
# Note:
#
#     Lets Read data & perform basic analysis !
#     # data pre-processing, CSV file I/O (e.g. pd.read_csv)
#     # import it for numerical computation on data
#     ## data viz libraries
#
#     Doing Data Pre-processing !
#     Check whether data-types are correct or not
#     check whether Data have missing value or not
#     check whether data have duplicate entries or not !
#     Now sort the dataset from oldest - recent
#     Analysing change in price of the stock overtime?
#     Analysing open , high , low , close value of Bitcoin !
#     try out candle-stick/ohlc charts ! , both are same
#     analysing Daily change in Closing price of stocks

# %% [markdown]
# # . Lets Read data & perform basic analysis !

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings .filterwarnings ('ignore')

# %%
import plotly.graph_objs as go
import plotly.express as px

from plotly.offline import download_plotlyjs,iplot,plot,init_notebook_mode

# %%
# Dynamic plot for this package


import plotly.graph_objs as go
import plotly.express as px
import plotly as py
import cufflinks as cf
from plotly.offline import download_plotlyjs,iplot,plot,init_notebook_mode

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# read dataframe 

df=pd.read_csv(r"C:\Users\DELL\Downloads\Internships\Udemy\Bitcoin_analysis\bitcoin_price_Training - Training.csv")

# %%
# take a sollow copy of a data


copy=df.copy()

# %%
# let us find the column index


df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')

# %%
# first five rows in dataframe



df.head()
# Out:
#            Date     Open     High      Low    Close         Volume  \
# 0  Jul 31, 2017  2763.24  2889.62  2720.61  2875.34    860,575,000
# 1  Jul 30, 2017  2724.39  2758.53  2644.85  2757.18    705,943,000
# 2  Jul 29, 2017  2807.02  2808.76  2692.80  2726.45    803,746,000
# 3  Jul 28, 2017  2679.73  2897.45  2679.73  2809.01  1,380,100,000
# 4  Jul 27, 2017  2538.71  2693.32  2529.34  2671.78    789,104,000
#
#        Market Cap
# 0  45,535,800,000
# 1  44,890,700,000
# 2  46,246,700,000
# 3  44,144,400,000
# 4  41,816,500,000

# %%
# Shape of a data


df.shape
# Out:
# (1556, 7)

# %%
# check the data type

df.dtypes
# Out:
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume         object
# Market Cap     object
# dtype: object

# %%
# Check the the information about the data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1556 entries, 0 to 1555
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1556 non-null   object
#  1   Open        1556 non-null   float64
#  2   High        1556 non-null   float64
#  3   Low         1556 non-null   float64
#  4   Close       1556 non-null   float64
#  5   Volume      1556 non-null   object
#  6   Market Cap  1556 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 85.2+ KB

# %%
# findout the five piont summary



df.describe().transpose()
# Out:
#         count        mean         std    min       25%      50%       75%  \
# Open   1556.0  582.625328  523.137312  68.50  254.2875  438.600  662.4375
# High   1556.0  597.992847  542.992855  74.56  260.3275  447.560  674.5250
# Low    1556.0  567.851446  505.877401  65.53  248.8350  430.570  646.7350
# Close  1556.0  584.239396  525.904442  68.43  254.3200  438.855  663.4025
#
#            max
# Open   2953.22
# High   2999.91
# Low    2840.53
# Close  2958.11

# %% [markdown]
# # Doing Data Pre-processing !
#     Check whether data-types are correct or not
#     check whether Data have missing value or not
#     check whether data have duplicate entries or not !

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')

# %%
df.dtypes
# Out:
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume         object
# Market Cap     object
# dtype: object

# %%
'''
pandas Data Type for Time-Series : 
    a ) datetime64[ns]
datetime64[ns] is a 64 bit number ie it uses/occupies 64 bits or 8-Bytes in computer memory to store datetime value ..

    b ) datetime64[ns, tz]

    c ) datetime64[ns, UTC]
    

    d ) dtype('<M8[ns]') or dtype('>M8[ns]')
 
## < represents byte order, small end （ the least significant byte is stored in the smallest address ）
## M is a type character code for Datetime
## 8 represents element byte length, data size ie 8-byte or 64 bit 




    where UTC = Coordinated Universal Time
          ns  = nano second
          tz  = time zone


'''
# Out:
# "\npandas Data Type for Time-Series : \n    a ) datetime64[ns]\ndatetime64[ns] is a 64 bit number ie it uses/occupies 64 bits or 8-Bytes in computer memory to store datetime value ..\n\n    b ) datetime64[ns, tz]\n\n    c ) datetime64[ns, UTC]\n    \n\n    d ) dtype('<M8[ns]') or dtype('>M8[ns]')\n \n## < represents byte order, small end （ the least significant byte is stored in the smallest address ）\n## M is a type character code for Datetime\n## 8 represents element byte length, data size ie 8-byte or 64 bit \n\n\n\n\n    where UTC = Coordinated Universal Time\n          ns  = nano second\n          tz  = time zone\n\n\n"

# %%
'''

datetime64[ns] is a general dtype, while dtype('<M8[ns]') is a specific dtype ,

Both are similar , it entirely depends upon how your numpy was compiled & on the bit architecture of the OS ..

Now architecture of numpy itself depends upon lots of factors like 
what environment u are using , what about the generation of your laptop too..


But if u want to think it bluntly , they are same..
By the way ,u can cross_check using below code:

import numpy as np
np.dtype('datetime64[ns]') == np.dtype('<M8[ns]')

'''
# Out:
# "\n\ndatetime64[ns] is a general dtype, while dtype('<M8[ns]') is a specific dtype ,\n\nBoth are similar , it entirely depends upon how your numpy was compiled & on the bit architecture of the OS ..\n\nNow architecture of numpy itself depends upon lots of factors like \nwhat environment u are using , what about the generation of your laptop too..\n\n\nBut if u want to think it bluntly , they are same..\nBy the way ,u can cross_check using below code:\n\nimport numpy as np\nnp.dtype('datetime64[ns]') == np.dtype('<M8[ns]')\n\n"

# %%
# change the data type to respective datatype
### convert feature into date-time
### since we have converted feature into date-time using pd.to_datetime() couple of times so lets use astype('datetime64[ns]')


df['Date']=df['Date'].astype('datetime64[ns]')


# or pd.to_datetime()

# %%
# get minimum  value

df['Date'].min()
# Out:
# Timestamp('2013-04-28 00:00:00')

# %%
# get maxmium value


df['Date'].max()
# Out:
# Timestamp('2017-07-31 00:00:00')

# %% [markdown]
# all data collected from 2013-04-28 and 2017-07-31 and Timestamp is just replace of datetime features in python  and it is belongs to scaler class

# %%
### Note : Each row in the "Date" column will belong to timestamp & "Date" Feature data-type will be datetime64[ns]..
## Timestamp is the pandas equivalent of python’s Datetime module..

# %%
type(df['Date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# checking  missing values

df.isnull().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Market Cap    0
# dtype: int64

# %%
# checking  percentage of missing values



df.isnull().sum()/df.shape[0]
# Out:
# Date          0.0
# Open          0.0
# High          0.0
# Low           0.0
# Close         0.0
# Volume        0.0
# Market Cap    0.0
# dtype: float64

# %%
# checking the duplicated values

df.duplicated().sum()
# Out:
# 0

# %%
# checking the percentage of   duplicated values 

df.duplicated().sum()/df.shape[0]
# Out:
# 0.0

# %% [markdown]
# # Now sort the dataset from oldest - recent

# %%
# to shows first five values in dataframe

df.head()
# Out:
#         Date     Open     High      Low    Close         Volume  \
# 0 2017-07-31  2763.24  2889.62  2720.61  2875.34    860,575,000
# 1 2017-07-30  2724.39  2758.53  2644.85  2757.18    705,943,000
# 2 2017-07-29  2807.02  2808.76  2692.80  2726.45    803,746,000
# 3 2017-07-28  2679.73  2897.45  2679.73  2809.01  1,380,100,000
# 4 2017-07-27  2538.71  2693.32  2529.34  2671.78    789,104,000
#
#        Market Cap
# 0  45,535,800,000
# 1  44,890,700,000
# 2  46,246,700,000
# 3  44,144,400,000
# 4  41,816,500,000

# %%
# to shows last five values in dataframe


df.tail()
# Out:
#            Date    Open    High     Low   Close Volume     Market Cap
# 1551 2013-05-02  116.38  125.60   92.28  105.21      -  1,292,190,000
# 1552 2013-05-01  139.00  139.89  107.72  116.99      -  1,542,820,000
# 1553 2013-04-30  144.00  146.93  134.05  139.00      -  1,597,780,000
# 1554 2013-04-29  134.44  147.49  134.00  144.54      -  1,491,160,000
# 1555 2013-04-28  135.30  135.98  132.10  134.21      -  1,500,520,000

# %%
# short the values from oldest to newest one
 
data=df.sort_index(ascending=False).reset_index()

# %% [markdown]
# # Analysing change in price of the stock overtime?

# %%
# revome the index for further analysis

 
data.drop('index',axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')

# %%
# creating simple  subplot  from the data

plt.figure(figsize=(25,13))
for index,col in enumerate(['Open', 'High', 'Low', 'Close'],1):
    plt.subplot(2,2,index)
    plt.plot(df['Date'],df[col])
    plt.title(col)

# %%
## let us change the color of the simple  subplot  from the data



plt.figure(figsize=(25,13))

colors=['red','green','purple','orange']


for index,col in enumerate(['Open', 'High', 'Low', 'Close'],1):
    plt.subplot(2,2,index)
    plt.plot(df['Date'],df[col],color=colors[index-1])
    plt.title(col)

# %%
data1=data.set_index('Date')

# %%
# analysis  the closing price

# Normal  Scaling 
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
data1['Close'].plot()
plt.title('Normal Scaling')

# Log  Scaling 
plt.subplot(1,2,2)
np.log1p(data1['Close']).plot()
plt.title('Log Scaling')
plt.yscale('log')

# %% [markdown]
# # EDA Analysis on yearly ,monthly,Quarterly  bases

# %%
# EDA Analysis on yearly ,monthly,Quarterly  bases


data1.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')

# %%
# EDA Analysis on yearly average  changes in closing price

data1['Close'].resample('Y').mean()
# Out:
# Date
# 2013-12-31     257.474476
# 2014-12-31     527.236658
# 2015-12-31     272.453260
# 2016-12-31     568.492131
# 2017-12-31    1628.622123
# Freq: A-DEC, Name: Close, dtype: float64

# %%
# EDA Analysis on yearly average  changes in closing price in Graph


data1['Close'].resample('Y').mean().plot(color='Green')
plt.xlabel("Yearly  Average  Changes")
plt.ylabel("Closing price")
plt.title("Yearly  Average Change's in Closing Prices ")
# Out:
# Text(0.5, 1.0, "Yearly  Average Change's in Closing Prices ")

# %% [markdown]
# # Analysing open , high , low , close value of Bitcoin !
# try out candle-stick/ohlc charts ! , both are same

# %%
import plotly.graph_objs as go
import plotly.express as px
import plotly as py
import cufflinks as cf
from plotly.offline import download_plotlyjs,iplot,plot,init_notebook_mode

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# year wise trends


data1['Close'].resample('Y').mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # EDA Analysis on Quaterly average changes in closing price in Graph

# %%
# EDA Analysis on Quaterly  chaverageanges in closing price

data1['Close'].resample("Q").mean()
# Out:
# Date
# 2013-06-30     115.162188
# 2013-09-30     111.291196
# 2013-12-31     502.657609
# 2014-03-31     700.586000
# 2014-06-30     520.929341
# 2014-09-30     534.055435
# 2014-12-31     357.075761
# 2015-03-31     251.209333
# 2015-06-30     236.858022
# 2015-09-30     254.859891
# 2015-12-31     346.037065
# 2016-03-31     410.728571
# 2016-06-30     512.492747
# 2016-09-30     615.702283
# 2016-12-31     732.721413
# 2017-03-31    1034.707444
# 2017-06-30    1912.552198
# 2017-09-30    2519.418387
# Freq: Q-DEC, Name: Close, dtype: float64

# %%
# EDA Analysis on Quaterly average changes in closing price

data1['Close'].resample('Q').mean().plot(color='purple')
plt.xlabel('Quaterly Changes')
plt.ylabel('Closing Price')
plt.title('Quaterly  Average Changes in Closing Price' )
# Out:
# Text(0.5, 1.0, 'Quaterly  Average Changes in Closing Price')

# %% [markdown]
# # EDA Analysis on monthly average changes in closing price in graph

# %%
# EDA Analysis on monthly average changes in closing price




data1['Close'].resample('m').mean()
# Out:
# Date
# 2013-04-30     139.250000
# 2013-05-31     119.993226
# 2013-06-30     107.761333
# 2013-07-31      90.512258
# 2013-08-31     113.905161
# 2013-09-30     130.061667
# 2013-10-31     158.311935
# 2013-11-30     550.420667
# 2013-12-31     800.780968
# 2014-01-31     844.168387
# 2014-02-28     661.618214
# 2014-03-31     592.200323
# 2014-04-30     461.362000
# 2014-05-31     486.651290
# 2014-06-30     615.917333
# 2014-07-31     618.025484
# 2014-08-31     536.087742
# 2014-09-30     445.186333
# 2014-10-31     364.150000
# 2014-11-30     366.100000
# 2014-12-31     341.268387
# 2015-01-31     248.782581
# 2015-02-28     234.153571
# 2015-03-31     269.041290
# 2015-04-30     235.491667
# 2015-05-31     236.996774
# 2015-06-30     238.081000
# 2015-07-31     279.563871
# 2015-08-31     250.734516
# 2015-09-30     233.595333
# 2015-10-31     264.855161
# 2015-11-30     348.883333
# 2015-12-31     424.464516
# 2016-01-31     410.844516
# 2016-02-29     404.408276
# ...

# %%
# EDA Analysis on monthly average changes in closing price in graph

data1['Close'].resample('m').mean().plot(color='Green')
plt.xlabel('Monthly Changes')
plt.ylabel('Closing Price')
plt.title('Monthly Average Changes in Closing Price' )
# Out:
# Text(0.5, 1.0, 'Monthly Average Changes in Closing Price')

# %%
# let us see in 3d format

import plotly.graph_objs as go
import plotly.express as px

from plotly.offline import download_plotlyjs,iplot,plot,init_notebook_mode

# %%
init_notebook_mode(connected=True) 
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
data1['Close'].resample('m').mean().iplot(color='Green')
# Out:
# <div>                            <div id="ae1b4a68-74fb-4bf8-a024-a5ede81c530e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # EDA Analysis on  Percentage of daily  changes in closing price   for that we pandas inbuilt or  default funtion [ data.pct_change() ]
#
#
#
#
# And  this  pie of [ data.pct_change() ] code automatically  compute changes because the default  period is 1.if want know more about this please rewrite the code blank column and press shift + tab it will show the documentation

# %% [raw]
# analysing Daily change in Closing price of stocks
# Daily Stock Return Formula
# To calculate how much you gained or lost per day for a stock, subtract the opening price from the closing price. Then, multiply the result by the number of shares you own in the company.

# %%
# EDA Analysis on daily changes

data1['Close']
# Out:
# Date
# 2013-04-28     134.21
# 2013-04-29     144.54
# 2013-04-30     139.00
# 2013-05-01     116.99
# 2013-05-02     105.21
#                ...
# 2017-07-27    2671.78
# 2017-07-28    2809.01
# 2017-07-29    2726.45
# 2017-07-30    2757.18
# 2017-07-31    2875.34
# Name: Close, Length: 1556, dtype: float64

# %%
data1['Close'].pct_change()
# Out:
# Date
# 2013-04-28         NaN
# 2013-04-29    0.076969
# 2013-04-30   -0.038328
# 2013-05-01   -0.158345
# 2013-05-02   -0.100692
#                 ...
# 2017-07-27    0.056269
# 2017-07-28    0.051363
# 2017-07-29   -0.029391
# 2017-07-30    0.011271
# 2017-07-31    0.042855
# Name: Close, Length: 1556, dtype: float64

# %%
data1['Close_pct_change']=data1['Close'].pct_change()*100

# %%
data1['Close_pct_change'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data1['Close_pct_change'].plot(kind='hist',color='blue')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # '''
#
# If u want to make this Pandas plot interactive , u can think of using cufflinks & Plotly
#
#
# '''

# %% [raw]
# ## let us install package and import library
#
#
# pip install cufflinks

# %%
import plotly.graph_objs as go
import plotly.express as px

from plotly.offline import download_plotlyjs,iplot,plot,init_notebook_mode

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data1['Close_pct_change'].iplot()
# Out:
# <div>                            <div id="60d18df9-df0a-49b4-8204-c9f696401e99" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# let us deep dive into Analysis of above one in stock graphs or candle stick graph



import plotly.graph_objs as go
import plotly.express as px

from plotly.offline import download_plotlyjs,iplot,plot,init_notebook_mode

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
trace = go.Candlestick(x=data['Date'],
                       open=data['Open'],
                       high=data['High'],
                       low=data['Low'],
                       close=data['Close'])

# %%
candle=[trace]

# %%
go.Figure(data=candle)
# Out:
# <div>                            <div id="3a3a83b0-e259-489b-a13f-a73c40cc80b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a3a83b0-e259-489b-a13f-a73c40cc80b0")) {                    Plotly.newPlot(                        "3a3a83b0-e259-489b-a13f-a73c40cc80b0",                        [{"close":[134.21,144.54,139.0,116.99,105.21,97.75,112.5,115.91,112.3,111.5,113.57,112.67,117.2,115.24,115.0,117.98,111.5,114.22,118.76,123.02,123.5,121.99,122.0,122.88,123.89,126.7,133.2,131.98,133.48,129.75,129.0,132.3,128.8,129.0,129.3,122.29,122.22,121.42,121.65,118.0,111.5,108.3,100.0,106.35,108.9,108.15,104.0,99.98,99.99,99.51,101.7,107.4,108.25,110.15,109.5,108.3,107.6,102.74,103.95,104.0,101.44,94.65,94.99,96.61,88.05,90.13,77.53,80.53,68.43,70.28,74.56,76
# ...

# %% [markdown]
# so the figure is not visible for us so we take sample from this make a chart

# %%
# let us take first 50 data 

#data.describe()
Bitcoin_sample=data[:50]

# %%
Ticket=go.Candlestick(x=Bitcoin_sample['Date'],
              open=Bitcoin_sample['Open'],
              close=Bitcoin_sample['Close'],
              high=Bitcoin_sample['High'],
              low=Bitcoin_sample['Low'])

# %%
go.Figure(Ticket)
# Out:
# <div>                            <div id="cb1ec0a0-167b-4fc3-9e17-968483a47e01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb1ec0a0-167b-4fc3-9e17-968483a47e01")) {                    Plotly.newPlot(                        "cb1ec0a0-167b-4fc3-9e17-968483a47e01",                        [{"close":[134.21,144.54,139.0,116.99,105.21,97.75,112.5,115.91,112.3,111.5,113.57,112.67,117.2,115.24,115.0,117.98,111.5,114.22,118.76,123.02,123.5,121.99,122.0,122.88,123.89,126.7,133.2,131.98,133.48,129.75,129.0,132.3,128.8,129.0,129.3,122.29,122.22,121.42,121.65,118.0,111.5,108.3,100.0,106.35,108.9,108.15,104.0,99.98,99.99,99.51],"high":[135.98,147.49,146.93,139.89,125.6,108.13,115.0,118.8,124.66,113.44,115.78,113.46,122.0,118.68,117.45,118.7,119.8,115.81,118.
# ...

# %%
# disable the layout for that 


fig=go.Figure(Ticket)


fig.update_layout(xaxis_rangeslider_visible=False)
# Out:
# <div>                            <div id="16357d2f-ff1b-4e9f-bbec-4c4a16707b38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16357d2f-ff1b-4e9f-bbec-4c4a16707b38")) {                    Plotly.newPlot(                        "16357d2f-ff1b-4e9f-bbec-4c4a16707b38",                        [{"close":[134.21,144.54,139.0,116.99,105.21,97.75,112.5,115.91,112.3,111.5,113.57,112.67,117.2,115.24,115.0,117.98,111.5,114.22,118.76,123.02,123.5,121.99,122.0,122.88,123.89,126.7,133.2,131.98,133.48,129.75,129.0,132.3,128.8,129.0,129.3,122.29,122.22,121.42,121.65,118.0,111.5,108.3,100.0,106.35,108.9,108.15,104.0,99.98,99.99,99.51],"high":[135.98,147.49,146.93,139.89,125.6,108.13,115.0,118.8,124.66,113.44,115.78,113.46,122.0,118.68,117.45,118.7,119.8,115.81,118.
# ...

# %%
# if you want to added title and xlabel layout it must be in string in dictionary  format

Ticket=go.Candlestick(x=Bitcoin_sample['Date'],
              open=Bitcoin_sample['Open'],
              close=Bitcoin_sample['Close'],
              high=Bitcoin_sample['High'],
              low=Bitcoin_sample['Low'])


layout={
    'title':'Bitcoin Historical Share Price',
    'xaxis':{'title':'Dates'}
}


fig = go.Figure(data=Ticket, layout=layout)

fig.update_layout(xaxis_rangeslider_visible=False)
# Out:
# <div>                            <div id="e60100c6-875a-4597-9d99-8071ba42d42c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e60100c6-875a-4597-9d99-8071ba42d42c")) {                    Plotly.newPlot(                        "e60100c6-875a-4597-9d99-8071ba42d42c",                        [{"close":[134.21,144.54,139.0,116.99,105.21,97.75,112.5,115.91,112.3,111.5,113.57,112.67,117.2,115.24,115.0,117.98,111.5,114.22,118.76,123.02,123.5,121.99,122.0,122.88,123.89,126.7,133.2,131.98,133.48,129.75,129.0,132.3,128.8,129.0,129.3,122.29,122.22,121.42,121.65,118.0,111.5,108.3,100.0,106.35,108.9,108.15,104.0,99.98,99.99,99.51],"high":[135.98,147.49,146.93,139.89,125.6,108.13,115.0,118.8,124.66,113.44,115.78,113.46,122.0,118.68,117.45,118.7,119.8,115.81,118.
# ...
